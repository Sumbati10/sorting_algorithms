# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = r"C:\Users\LENOVO\Downloads\KENYAN COUNTY_GEO\Landjob_2024.csv"

# Read the CSV file
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
df.head()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_21756\2705841181.py:7: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)
#         id                        created_at  \
# 0  1154342  2024-06-11 15:46:24.884924+00:00
# 1  1000280  2024-04-12 19:56:51.858323+00:00
# 2  1000284  2024-04-12 19:57:17.567992+00:00
# 3  1000285  2024-04-12 19:57:22.685770+00:00
# 4  1000286  2024-04-12 19:57:27.559368+00:00
#
#                          updated_at  source  activity_id  \
# 0  2024-06-11 19:03:26.544440+00:00      20       932756
# 1  2024-04-12 19:56:51.858345+00:00      30       871290
# 2  2024-04-12 19:57:17.568014+00:00      30       871400
# 3  2024-04-12 19:57:22.685789+00:00      30       871400
# 4  2024-04-12 19:57:27.559386+00:00      30       871400
#
#                 jobStartTime                 jobEndTime eventType      area  \
# 0  2024-06-11 11:18:15+00:00  2024-06-11 14:08:25+00:00       dbs  0.642436
# 1  2024-04-12 09:12:58+00:00  2024-04-12 18:07:32+00:00       NaN  2.789345
# 2  2024-04-12 09:05:19+00:00  2024-04-12 09:20:20+00:00       NaN  0.062322
# 3  2024-04-12 08:34:59+00:00  2024-04-12 09:02:19+00:00       NaN  0.042772
# 4  2024-04-12 09:27:43+00:00  2024-04-12 09:40:57+00:00       NaN  0.033859
#
#     distance  ... operator_id  state  trip_id  user_id  location_id  \
# 0   0.053252  ...         NaN    1.0      NaN   7840.0        639.0
# 1  34.619896  ...         NaN    1.0      NaN   7840.0        458.0
# 2   0.328432  ...         NaN    1.0      NaN     26.0        557.0
# 3   0.299703  ...         NaN    1.0      NaN     26.0        557.0
# 4   0.431969  ...         NaN    1.0      NaN     26.0        557.0
#
#    fuel_refuelled fuel_siphoned  net_fuel_consumed  approved deleted_at
# 0             0.0           0.0                0.0      True        NaN
# 1             0.0           0.0                0.0      True        NaN
# 2             0.0           0.0                0.0      True        NaN
# 3             0.0           0.0                0.0      True        NaN
# 4             0.0           0.0                0.0      True        NaN
#
# [5 rows x 30 columns]

# %%
from shapely.wkb import loads
from shapely.geometry import mapping
import pandas as pd

def wkb_to_geojson(wkb_string):
    try:
        # Convert hexadecimal string to bytes
        byte_data = bytes.fromhex(wkb_string)
        
        # Load geometry from bytes
        geometry = loads(byte_data, hex=False)  # Corrected parameter
        
        # Convert to GeoJSON format
        geojson = mapping(geometry)
        return geojson
    except Exception as e:
        print(f"Error processing WKB string '{wkb_string}': {e}")
        return None  # Return None or an appropriate value indicating failure

# Assuming df['polygon'] contains hexadecimal WKB strings
df['polygon_geojson'] = df['polygon'].apply(wkb_to_geojson)
# Out:
# Error processing WKB string '0103000020E61000000100000008000000268C6665FB3E414088A1D5C9198AC3BFEA25C632FD3E4140209BE447FC8AC3BFDEAB5626FC3E4140100533A6608DC3BFEA25C632FD3E4140DDB1D826158DC3BFF59F353FFE3E4140D63BDC0E0D8BC3BF520C': ParseException: Input buffer is smaller than requested object size
